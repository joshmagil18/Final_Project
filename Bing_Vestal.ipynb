# %%
import csv
with open("weather.csv") as weather:
    weather_data=csv.reader(weather)
    weather_rows=[row for row in weather_data]
    
weather_rows
# Out:
# [['STATION',
#   'NAME',
#   'LATITUDE',
#   'LONGITUDE',
#   'ELEVATION',
#   'DATE',
#   'DAPR',
#   'DAPR_ATTRIBUTES',
#   'MDPR',
#   'MDPR_ATTRIBUTES',
#   'PRCP',
#   'PRCP_ATTRIBUTES',
#   'SNOW',
#   'SNOW_ATTRIBUTES',
#   'SNWD',
#   'SNWD_ATTRIBUTES',
#   'WESD',
#   'WESD_ATTRIBUTES'],
#  ['US1NYBM0004',
#   'ENDICOTT 5.2 SSE, NY US',
#   '42.02958',
#   '-76.02129',
#   '317.0',
#   '2022-01-01',
#   '',
#   '',
#   '',
#   '',
#   '0.00',
#   ',,N',
#   '0.0',
#   ',,N',
#   '',
#   '',
#   '',
#   ''],
#  ['US1NYBM0004',
#   'ENDICOTT 5.2 SSE, NY US',
#   '42.02958',
#   '-76.02129',
#   '317.0',
#   '2022-01-02',
#   '',
#   '',
#   '',
#   '',
#   '0.10',
#   ',,N',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['US1NYBM0004',
#   'ENDICOTT 5.2 SSE, NY US',
#   '42.02958',
#   '-76.02129',
#   '317.0',
#   '2022-01-03',
#   '',
#   '',
#   '',
#   '',
#   '0.00',
#   'T,,N',
#   '0.0',
#   'T,,N',
#   '0.0',
#   'T,,N',
#   '',
#   ''],
#  ['US1NYBM0004',
# ...

# %%
import pandas as pd

bing=pd.read_csv("weather.csv")
bing
# Out:
#          STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0    US1NYBM0004  ENDICOTT 5.2 SSE, NY US  42.02958  -76.02129      317.0
# 1    US1NYBM0004  ENDICOTT 5.2 SSE, NY US  42.02958  -76.02129      317.0
# 2    US1NYBM0004  ENDICOTT 5.2 SSE, NY US  42.02958  -76.02129      317.0
# 3    US1NYBM0004  ENDICOTT 5.2 SSE, NY US  42.02958  -76.02129      317.0
# 4    US1NYBM0004  ENDICOTT 5.2 SSE, NY US  42.02958  -76.02129      317.0
# ..           ...                      ...       ...        ...        ...
# 192  US1NYBM0007    VESTAL 2.8 SSE, NY US  42.04930  -76.02883      303.0
# 193  US1NYBM0007    VESTAL 2.8 SSE, NY US  42.04930  -76.02883      303.0
# 194  US1NYBM0007    VESTAL 2.8 SSE, NY US  42.04930  -76.02883      303.0
# 195  US1NYBM0007    VESTAL 2.8 SSE, NY US  42.04930  -76.02883      303.0
# 196  US1NYBM0007    VESTAL 2.8 SSE, NY US  42.04930  -76.02883      303.0
#
#            DATE  DAPR DAPR_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PRCP  \
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

bing["PRCP"].value_counts().head().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='PRCP'>
